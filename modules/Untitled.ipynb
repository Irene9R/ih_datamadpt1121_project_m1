# %%
import pandas as pd
import numpy as np
import bs4
import requests
from shapely.geometry import Point

# %%
response = requests.get("https://datos.madrid.es/egob/catalogo/202318-0-escuelas-infantiles.json").json()
response.keys()
# Out:
# dict_keys(['@context', '@graph'])

# %%
response_normalize = pd.json_normalize(response["@graph"])
display(response_normalize)
# Out:
#                                                   @id  \
# 0   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3   https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4   https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                ...
# 56  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 57  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 58  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 59  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 60  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                 @type        id  \
# 0   https://datos.madrid.es/egob/kos/entidadesYorg...     58241
# 1   https://datos.madrid.es/egob/kos/entidadesYorg...   4549323
# 2   https://datos.madrid.es/egob/kos/entidadesYorg...   5299172
# ...

# %%
response
# Out:
# {'@context': {'c': 'http://www.w3.org/2002/12/cal#',
#   'dcterms': 'http://purl.org/dc/terms/',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'loc': 'http://purl.org/ctic/infraestructuras/localizacion#',
#   'org': 'http://purl.org/ctic/infraestructuras/organizacion#',
#   'vcard': 'http://www.w3.org/2006/vcard/ns#',
#   'schema': 'https://schema.org/',
#   'title': 'vcard:fn',
#   'id': 'dcterms:identifier',
#   'relation': 'dcterms:relation',
#   'references': 'dcterms:references',
#   'address': 'vcard:adr',
#   'area': 'loc:barrio',
#   'district': 'loc:distrito',
#   'locality': 'vcard:locality',
#   'postal-code': 'vcard:postal-code',
#   'street-address': 'vcard:street-address',
#   'location': 'vcard:geo',
#   'latitude': 'geo:lat',
#   'longitude': 'geo:long',
#   'organization': 'vcard:org',
#   'organization-desc': 'dcterms:description',
#   'accesibility': 'org:accesibilidad',
#   'services': 'org:servicios',
#   'schedule': 'org:horario',
# ...

# %%
x = requests.get("https://datos.madrid.es/egob/catalogo/202318-0-escuelas-infantiles.csv")

# %%
x.content.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25632/2611425605.py in <module>
# ----> 1 x.content.decode('utf-8')
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd1 in position 391: invalid continuation byte
